# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")

df.head()
# Out:
#          Date Order_ID   Product         Category Region  Sales  Quantity  \
# 0  2025-11-24  ORD1001     Phone      Electronics  North   1226         1
# 1  2025-12-13  ORD1002   Printer  Office Supplies  North   2518         2
# 2  2025-04-22  ORD1003     Chair        Furniture   West   2565         9
# 3  2025-04-23  ORD1004       Pen       Stationery  South   1239        10
# 4  2025-12-24  ORD1005  Notebook       Stationery   East   1238         6
#
#    Discount  Profit
# 0         5  158.28
# 1        15  219.05
# 2         0  521.91
# 3         0  305.96
# 4         5  157.68

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      200 non-null    datetime64[us]
#  1   Order_ID  200 non-null    str
#  2   Product   200 non-null    str
#  3   Category  200 non-null    str
#  4   Region    200 non-null    str
#  5   Sales     200 non-null    int64
#  6   Quantity  200 non-null    int64
#  7   Discount  200 non-null    int64
#  8   Profit    200 non-null    float64
# dtypes: datetime64[us](1), float64(1), int64(3), str(4)
# memory usage: 19.7 KB

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("charts", exist_ok=True)

daily_sales = df.groupby("Date")["Sales"].sum()

plt.figure(figsize=(12,6))

plt.plot(daily_sales.index,
         daily_sales.values,
         marker='o')

plt.title("Daily Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("charts/daily_sales.png")

plt.show()
